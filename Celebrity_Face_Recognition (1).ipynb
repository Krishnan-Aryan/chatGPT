# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2
import zipfile
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# !unzip '/content/drive/MyDrive/data_set/Celebrity_pics.zip' -d extracted_files
# Out:
# Archive:  /content/drive/MyDrive/data_set/Celebrity_pics.zip
# replace extracted_files/Celebrity_pics/Nayan_Thara/NN29.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
img=cv2.imread('extracted_files/Celebrity_pics/Nayan_Thara/NN34.jpg')

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1350, 1080)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# %%
# Load the image
image = cv2.imread('extracted_files/Celebrity_pics/Nayan_Thara/NN34.jpg')

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces
face = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Iterate over detected faces
for (x, y, w, h) in face:
    # Crop the face from the image
    face = image[y:y+h, x:x+w]

    # Detect eyes within the face region
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    if len(eyes) >= 2:
        # Display the cropped face where both eyes are visible.
      plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
      plt.axis('off')
      plt.show()

# %%
path_to_data = "extracted_files/Celebrity_pics"
path_to_cr_data = "/content/drive/MyDrive/data_set/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['extracted_files/Celebrity_pics/Sharukh_Khan',
#  'extracted_files/Celebrity_pics/Alia_Bhutt',
#  'extracted_files/Celebrity_pics/Fahad_Fazil',
#  'extracted_files/Celebrity_pics/Ryan_Gossling',
#  'extracted_files/Celebrity_pics/Manju_Varrier',
#  'extracted_files/Celebrity_pics/Nayan_Thara']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".jpg"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  /content/drive/MyDrive/data_set/cropped/Fahad_Fazil
# Generating cropped images in folder:  /content/drive/MyDrive/data_set/cropped/Sharukh_Khan
# Generating cropped images in folder:  /content/drive/MyDrive/data_set/cropped/Alia_Bhutt
# Generating cropped images in folder:  /content/drive/MyDrive/data_set/cropped/Ryan_Gossling
# Generating cropped images in folder:  /content/drive/MyDrive/data_set/cropped/Nayan_Thara
# Generating cropped images in folder:  /content/drive/MyDrive/data_set/cropped/Manju_Varrier

# %% [markdown]
# ##**Feature Extraction**

# %%
import pywt


def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)
    imArray /= 255;
    # compute coefficients
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)
    coeffs_H[0] *= 0;

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(face,'haar',6)
plt.imshow(im_har, cmap='gray')

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
cropped_image_dirs=['/content/drive/MyDrive/data_set/cropped/Sharukh_Khan',
                    '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt',
                    '/content/drive/MyDrive/data_set/cropped/Manju_Varrier',
                    '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling',
                    '/content/drive/MyDrive/data_set/cropped/Nayan_Thara',
                    '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil']

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Sharukh_Khan': ['/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan1.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan2.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan3.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan4.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan5.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan6.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan7.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan9.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan10.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan11.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan12.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan13.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan14.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan15.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan16.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan17.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan18.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan19.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan20.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan21.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan22.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan24.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan25.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan26.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan27.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan28.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan31.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan32.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan33.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan34.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan35.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan36.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan37.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan38.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Sharukh_Khan/Sharukh_Khan39.jpg'],
#  'Alia_Bhutt': ['/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt1.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt2.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt3.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt4.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt5.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt6.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt7.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt8.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt9.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt10.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt11.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt12.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt13.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt14.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt15.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt16.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt17.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt18.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt19.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt20.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt21.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt22.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt23.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt24.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt25.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt26.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt27.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt28.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt29.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt30.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt31.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt32.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt33.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt34.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Alia_Bhutt/Alia_Bhutt35.jpg'],
#  'Manju_Varrier': ['/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier1.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier2.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier3.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier4.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier5.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier6.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier7.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier8.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier9.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier10.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier11.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier12.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier13.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier14.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier15.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier16.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier17.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier18.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier19.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier20.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier21.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier22.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier23.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier25.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier27.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier28.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier29.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier30.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier31.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier32.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier33.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier34.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier35.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier36.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Manju_Varrier/Manju_Varrier37.jpg'],
#  'Ryan_Gossling': ['/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling1.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling2.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling3.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling4.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling5.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling7.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling8.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling9.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling10.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling11.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling13.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling14.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling15.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling16.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling17.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling18.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling19.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling21.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling22.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling24.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling25.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling27.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling28.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling30.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling31.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling32.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling33.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling34.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling35.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling36.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling38.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling39.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling41.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling42.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Ryan_Gossling/Ryan_Gossling44.jpg'],
#  'Nayan_Thara': ['/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara1.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara2.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara3.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara4.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara5.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara7.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara8.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara9.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara10.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara11.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara12.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara13.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara14.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara15.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara16.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara17.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara18.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara19.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara21.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara22.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara23.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara24.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara25.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara26.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara27.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara28.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara30.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara32.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara33.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara34.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara35.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara36.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara37.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara38.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Nayan_Thara/Nayan_Thara40.jpg'],
#  'Fahad_Fazil': ['/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil35.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil34.jpeg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil36.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil37.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil38.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil1.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil2.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil3.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil5.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil6.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil7.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil8.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil9.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil11.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil12.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil13.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil14.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil15.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil16.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil17.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil18.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil19.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil20.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil23.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil24.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil25.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil26.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil27.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil28.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil29.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil30.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil31.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil32.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil33.jpg',
#   '/content/drive/MyDrive/data_set/cropped/Fahad_Fazil/Fahad_Fazil40.jpg']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Sharukh_Khan': 0,
#  'Alia_Bhutt': 1,
#  'Manju_Varrier': 2,
#  'Ryan_Gossling': 3,
#  'Nayan_Thara': 4,
#  'Fahad_Fazil': 5}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
type(X)
# Out:
# list

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (0, 4096)

# %%
X
# Out:
# array([[ 15.,  15.,  15., ...,   1., 249., 252.],
#        [  0.,   0.,   0., ...,   1.,   0.,   0.],
#        [ 17.,  15.,  15., ..., 244., 237., 234.],
#        ...,
#        [104., 109., 112., ...,  82.,   6.,   6.],
#        [251., 245., 240., ..., 234., 225.,  61.],
#        [123., 125., 132., ..., 183.,   4., 250.]])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6981132075471698

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.40      0.42        10
#            1       0.75      0.43      0.55         7
#            2       0.70      0.64      0.67        11
#            3       0.91      1.00      0.95        10
#            4       0.89      1.00      0.94         8
#            5       0.50      0.71      0.59         7
#
#     accuracy                           0.70        53
#    macro avg       0.70      0.70      0.69        53
# weighted avg       0.70      0.70      0.69        53

# %%
from google.colab.patches import cv2_imshow

# %%
X,y=[],[]
for celeb, images in celebrity_file_names_dict.items():
    for image in images:
        img = cv2.imread(image)
        resized_img = cv2.resize(img, (128, 128))  # Resize the image
        nor_img = resized_img / 255.0  # Normalize the resized image
        X.append(nor_img)
        y.append(class_dict[celeb])

# %%
len(X)
# Out:
# 210

# %%
from sklearn.utils import shuffle

X, y = shuffle(X, y, random_state=42)

# %%
plt.imshow(X[46])

# %%
y[46]
# Out:
# 4

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_stacked = np.stack(X_train)
X_reshaped = X_stacked.reshape(-1, 128, 128, 3)
X_train = X_reshaped.astype('float32')

# %%
X_train.shape
# Out:
# (157, 128, 128, 3)

# %%
y_train=np.array(y_train)
y_test=np.array(y_test)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import Sequential,models,layers,regularizers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten,Dense

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(6, activation='softmax')  # Number of classes as the output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 3305414 (12.61 MB)
# Trainable params: 3305414 (12.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=model.fit(X_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 5s 299ms/step - loss: 2.0692 - accuracy: 0.1600 - val_loss: 1.7729 - val_accuracy: 0.3438
# Epoch 2/10
# 4/4 [==============================] - 0s 26ms/step - loss: 1.7738 - accuracy: 0.2480 - val_loss: 1.7734 - val_accuracy: 0.3125
# Epoch 3/10
# 4/4 [==============================] - 0s 27ms/step - loss: 1.7374 - accuracy: 0.3440 - val_loss: 1.7440 - val_accuracy: 0.3750
# Epoch 4/10
# 4/4 [==============================] - 0s 28ms/step - loss: 1.6642 - accuracy: 0.4240 - val_loss: 1.6917 - val_accuracy: 0.5000
# Epoch 5/10
# 4/4 [==============================] - 0s 30ms/step - loss: 1.4977 - accuracy: 0.5920 - val_loss: 1.5620 - val_accuracy: 0.4375
# Epoch 6/10
# 4/4 [==============================] - 0s 26ms/step - loss: 1.2004 - accuracy: 0.5840 - val_loss: 1.2726 - val_accuracy: 0.6250
# Epoch 7/10
# 4/4 [==============================] - 0s 29ms/step - loss: 0.8828 - accuracy: 0.6880 - val_loss: 1.1398 - val_accuracy: 0.4688
# Epoch 8/10
# 4/4 [==============================] - 0s 31ms/step - loss: 0.7572 - accuracy: 0.7440 - val_loss: 1.0082 - val_accuracy: 0.5312
# Epoch 9/10
# 4/4 [==============================] - 0s 25ms/step - loss: 0.5668 - accuracy: 0.7680 - val_loss: 1.1862 - val_accuracy: 0.4375
# Epoch 10/10
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4012 - accuracy: 0.8960 - val_loss: 0.8993 - val_accuracy: 0.6250

# %%
X_stacked = np.stack(X_test)
X_reshaped = X_stacked.reshape(-1, 128, 128, 3)
X_test = X_reshaped.astype('float32')

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 2/2 [==============================] - 0s 176ms/step - loss: 1.2535 - accuracy: 0.5283
# Test accuracy: 0.5283018946647644

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# 2/2 [==============================] - 1s 155ms/step - loss: 2.0052 - accuracy: 0.4906
# Test accuracy: 0.49056604504585266

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
    fill_mode='nearest'
)

# %%
num_augmentations = 30
X_train_augmented = []
y_train_augmented = []

# %%
for i in range(len(X_train)):
    x = X_train[i].reshape((1,) + X_train[i].shape)  # Reshape the image to (1, 128, 128, 3)
    y = y_train[i]

    # Generate augmented images
    aug_iter = datagen.flow(x, batch_size=1)
    for _ in range(num_augmentations):
        aug_image = next(aug_iter)[0]  # Extract the image from the batch
        X_train_augmented.append(aug_image)
        y_train_augmented.append(y)

# %%
len(X_train_augmented)
# Out:
# 5010

# %%
plt.imshow(X_train_augmented[458])

# %%
# Convert lists to numpy arrays
X_train_augmented = np.array(X_train_augmented)
y_train_augmented = np.array(y_train_augmented)

# Append the augmented images and labels to the original dataset
X_train_expanded = np.concatenate((X_train, X_train_augmented), axis=0)
y_train_expanded = np.concatenate((y_train, y_train_augmented), axis=0)

# %%
print("Original X_train shape:", X_train.shape)
print("Expanded X_train shape:", X_train_expanded.shape)
print("Original y_train shape:", y_train.shape)
print("Expanded y_train shape:", y_train_expanded.shape)
# Out:
# Original X_train shape: (157, 128, 128, 3)
# Expanded X_train shape: (5167, 128, 128, 3)
# Original y_train shape: (157,)
# Expanded y_train shape: (5167,)

# %%
X_train_expanded,y_train_expanded=shuffle(X_train_expanded,y_train_expanded,random_state=42)

# %%
X_train_expanded.shape
# Out:
# (5167, 128, 128, 3)

# %%
def wavelet_transform(image):
    coeffs2 = pywt.dwt2(image, 'haar')  # 2D wavelet transform
    LL, (LH, HL, HH) = coeffs2
    transformed_image = np.hstack((LL, LH, HL, HH))  # Stack coefficients
    return transformed_image

# Function to process and stack images
def process_and_stack_images(X):
    processed_images = []
    for image in X:
        transformed_image = wavelet_transform(image)
        stacked_image = np.hstack((image.reshape(-1), transformed_image.reshape(-1)))  # Stack as 1D arrays
        processed_images.append(stacked_image)
    return processed_images

# %%
processed_X_train = process_and_stack_images(X_train)

# %%
processed_X_train = np.array(processed_X_train)
processed_X_train.shape
# Out:
# (3297, 114688)

# %%
processed_X_test = process_and_stack_images(X_test)

# %%
model_aug = models.Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(6)
])

model_aug.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history_aug=model_aug.fit in(X_train_expanded, y_train_expanded, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 83/83 [==============================] - 45s 495ms/step - loss: 1.5048 - accuracy: 0.3777 - val_loss: 1.0185 - val_accuracy: 0.6409
# Epoch 2/10
# 83/83 [==============================] - 45s 546ms/step - loss: 0.6824 - accuracy: 0.7607 - val_loss: 0.6334 - val_accuracy: 0.7970
# Epoch 3/10
# 83/83 [==============================] - 42s 508ms/step - loss: 0.3440 - accuracy: 0.8824 - val_loss: 0.3837 - val_accuracy: 0.8742
# Epoch 4/10
# 83/83 [==============================] - 43s 516ms/step - loss: 0.1847 - accuracy: 0.9401 - val_loss: 0.3262 - val_accuracy: 0.8727
# Epoch 5/10
# 83/83 [==============================] - 41s 491ms/step - loss: 0.1725 - accuracy: 0.9446 - val_loss: 0.2627 - val_accuracy: 0.9030
# Epoch 6/10
# 83/83 [==============================] - 45s 543ms/step - loss: 0.0883 - accuracy: 0.9693 - val_loss: 0.2818 - val_accuracy: 0.8939
# Epoch 7/10
# 83/83 [==============================] - 44s 528ms/step - loss: 0.0419 - accuracy: 0.9879 - val_loss: 0.1447 - val_accuracy: 0.9470
# Epoch 8/10
# 83/83 [==============================] - 43s 520ms/step - loss: 0.0292 - accuracy: 0.9913 - val_loss: 0.2141 - val_accuracy: 0.9333
# Epoch 9/10
# 83/83 [==============================] - 43s 524ms/step - loss: 0.0261 - accuracy: 0.9928 - val_loss: 0.1922 - val_accuracy: 0.9227
# Epoch 10/10
# 83/83 [==============================] - 44s 531ms/step - loss: 0.0191 - accuracy: 0.9962 - val_loss: 0.1565 - val_accuracy: 0.9515

# %%
test_loss, test_acc = model_aug.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_aug.history['accuracy'])
plt.plot(history_aug.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_aug.history['loss'])
plt.plot(history_aug.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2356 - accuracy: 0.7547
# Test accuracy: 0.7547169923782349

# %%
model_aug2 = models.Sequential([
    layers.Conv2D(16, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(32, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(64, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Flatten(),
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.4),
    layers.Dense(6)
])

model_aug2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
history_aug2 = model_aug2.fit(
    X_train_expanded, y_train_expanded,
    epochs=5,
    validation_split=0.2,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/5
# 130/130 [==============================] - 4s 32ms/step - loss: 0.4197 - accuracy: 0.9274 - val_loss: 0.3623 - val_accuracy: 0.9623
# Epoch 2/5
# 130/130 [==============================] - 3s 21ms/step - loss: 0.4107 - accuracy: 0.9335 - val_loss: 0.3175 - val_accuracy: 0.9807
# Epoch 3/5
# 130/130 [==============================] - 2s 17ms/step - loss: 0.3999 - accuracy: 0.9402 - val_loss: 0.3189 - val_accuracy: 0.9710
# Epoch 4/5
# 130/130 [==============================] - 2s 16ms/step - loss: 0.3982 - accuracy: 0.9388 - val_loss: 0.4083 - val_accuracy: 0.9400
# Epoch 5/5
# 130/130 [==============================] - 2s 16ms/step - loss: 0.3836 - accuracy: 0.9429 - val_loss: 0.3244 - val_accuracy: 0.9749

# %%
test_loss, test_acc = model_aug2.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_aug2.history['accuracy'])
plt.plot(history_aug2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_aug2.history['loss'])
plt.plot(history_aug2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5789 - accuracy: 0.6981
# Test accuracy: 0.698113203048706

# %%
model_aug2.save('my_model_aug2.h5')  # Save the model in HDF5 format
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# !cp my_model_aug2.h5 /content/drive/MyDrive/

# %%
import pickle

# Assuming `model` is your trained model
with open('model_aug2_1.pkl', 'wb') as file:
    pickle.dump(model_aug2, file)

# %%
# Copy the model to Google Drive
# !cp model_aug2_1.pkl /content/drive/MyDrive/
